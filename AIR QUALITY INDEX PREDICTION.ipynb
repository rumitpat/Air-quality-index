# %%
import os
import time
import requests
import sys


def retrieve_html():
    for year in range(2013,2020):
        for month in range(1,13):
            if(month<10):
                url='http://en.tutiempo.net/climate/0{}-{}/ws-427370.html'.format(month
                                                                          ,year)
            else:
                url='http://en.tutiempo.net/climate/{}-{}/ws-427370.html'.format(month
                                                                          ,year)
            texts=requests.get(url)
            text_utf=texts.text.encode('utf=8')
            
            if not os.path.exists("Untitled Folder 3/Html_Untitled Folder 3/{}".format(year)):
                os.makedirs("Untitled Folder 3/Html_Untitled Folder 3/{}".format(year))
            with open("Untitled Folder 3/Html_Untitled Folder 3/{}/{}.html".format(year,month),"wb") as output:
                output.write(text_utf)
            
        sys.stdout.flush()
        
if __name__=="__main__":
    start_time=time.time()
    retrieve_html()
    stop_time=time.time()
    print("Time taken {}".format(stop_time-start_time))

# %%
import pandas as pd
import matplotlib.pyplot as plt


def avg_data_2013():
    
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2013.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2014():
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2014.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2015():
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2015.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average

    
def avg_data_2016():
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2016.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2017():
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2017.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2018():
    temp_i=0
    average=[]
    for rows in pd.read_csv('AQI-Project-master/Data/AQI/aqi2018.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    

if __name__=="__main__":
    lst2013=avg_data_2013()
    lst2014=avg_data_2014()
    lst2015=avg_data_2015()
    lst2016=avg_data_2016()
    lst2017=avg_data_2017()
    lst2018=avg_data_2018()

# %%
    plt.plot(range(0,365),lst2013,label="2013 data")
    plt.plot(range(0,364),lst2014,label="2014 data")
    plt.plot(range(0,365),lst2015,label="2015 data")
    plt.plot(range(0,365),lst2016,label="2016 data")
    plt.plot(range(0,365),lst2017,label="2017 data")
    plt.plot(range(0,364),lst2018,label="2018 data")
    plt.xlabel('Day')
    plt.ylabel('PM 2.5')
    plt.legend(loc='upper right')
    plt.show()

# %%
print(len(lst2013))
print(len(lst2014))
print(len(lst2015))
print(len(lst2016))
print(len(lst2017))
print(len(lst2018))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eadb2f1c0fcf> in <module>
# ----> 1 print(len(lst2013))
#       2 print(len(lst2014))
#       3 print(len(lst2015))
#       4 print(len(lst2016))
#       5 print(len(lst2017))
#
# NameError: name 'lst2013' is not defined

# %%
from bs4 import BeautifulSoup

# %%
import requests
import sys
import pandas as pd
from bs4 import BeautifulSoup
import os
import csv

def met_data(month, year):
    
    file_html = open('Data/Html_Data/{}/{}.html'.format(year,month), 'rb')
    plain_text = file_html.read()

    tempD = []
    finalD = []

    soup = BeautifulSoup(plain_text)
    for table in soup.findAll('table', {'class': 'medias mensuales numspan'}):
        for tbody in table:
            for tr in tbody:
                a = tr.get_text()
                tempD.append(a)

    rows = len(tempD) / 15

    for times in range(round(rows)):
        newtempD = []
        for i in range(15):
            newtempD.append(tempD[0])
            tempD.pop(0)
        finalD.append(newtempD)

    length = len(finalD)

    finalD.pop(length - 1)
    finalD.pop(0)

    for a in range(len(finalD)):
        finalD[a].pop(6)
        finalD[a].pop(13)
        finalD[a].pop(12)
        finalD[a].pop(11)
        finalD[a].pop(10)
        finalD[a].pop(9)
        finalD[a].pop(0)

    return finalD

def data_combine(year, cs):
    for a in pd.read_csv('Data/Real-Data/real_' + str(year) + '.csv', chunksize=cs):
        df = pd.DataFrame(data=a)
        mylist = df.values.tolist()
    return mylist


if __name__ == "__main__":
    if not os.path.exists("Data/Real-Data"):
        os.makedirs("Data/Real-Data")
    for year in range(2013, 2017):
        final_data = []
        with open('Data/Real-Data/real_' + str(year) + '.csv', 'w') as csvfile:
            wr = csv.writer(csvfile, dialect='excel')
            wr.writerow(
                ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'])
        for month in range(1, 13):
            temp = met_data(month, year)
            final_data = final_data + temp
            
        pm = getattr(sys.modules[__name__], 'avg_data_{}'.format(year))()

        if len(pm) == 364:
            pm.insert(364, '-')

        for i in range(len(final_data)-1):
            # final[i].insert(0, i + 1)
            final_data[i].insert(8, pm[i])

        with open('Data/Real-Data/real_' + str(year) + '.csv', 'a') as csvfile:
            wr = csv.writer(csvfile, dialect='excel')
            for row in final_data:
                flag = 0
                for elem in row:
                    if elem == "" or elem == "-":
                        flag = 1
                if flag != 1:
                    wr.writerow(row)
                    
    data_2013 = data_combine(2013, 600)
    data_2014 = data_combine(2014, 600)
    data_2015 = data_combine(2015, 600)
    data_2016 = data_combine(2016, 600)
     
    total=data_2013+data_2014+data_2015+data_2016
    
    with open('Data/Real-Data/Real_Combine.csv', 'w') as csvfile:
        wr = csv.writer(csvfile, dialect='excel')
        wr.writerow(
            ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'])
        wr.writerows(total)
        
        
df=pd.read_csv('Data/Real-Data/Real_Combine.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("AQI-Project-master/Data/Real-Data/Real_Combine.csv")
data.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
data.shape
# Out:
# (1093, 9)

# %%
#check the null value
data.isnull()
# Out:
#           T     TM     Tm    SLP      H     VV      V     VM  PM 2.5
# 0     False  False  False  False  False  False  False  False   False
# 1     False  False  False  False  False  False  False  False   False
# 2     False  False  False  False  False  False  False  False   False
# 3     False  False  False  False  False  False  False  False   False
# 4     False  False  False  False  False  False  False  False   False
# ...     ...    ...    ...    ...    ...    ...    ...    ...     ...
# 1088  False  False  False  False  False  False  False  False   False
# 1089  False  False  False  False  False  False  False  False   False
# 1090  False  False  False  False  False  False  False  False   False
# 1091  False  False  False  False  False  False  False  False   False
# 1092  False  False  False  False  False  False  False  False   False
#
# [1093 rows x 9 columns]

# %%
data[data["PM 2.5"].isnull()]
data =data.dropna()

# %%
data.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %%
real_x =data.iloc[:,0:8]
real_y =data.iloc[:,8]

# %%
real_y
# Out:
# 0       219.720833
# 1       182.187500
# 2       154.037500
# 3       223.208333
# 4       200.645833
#            ...
# 1088    288.416667
# 1089    256.833333
# 1090    169.000000
# 1091    186.041667
# 1092    185.583333
# Name: PM 2.5, Length: 1092, dtype: float64

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967536  0.953719 -0.881409 -0.509299  0.640792  0.301994
# TM      0.967536  1.000000  0.892031 -0.822958 -0.586681  0.606945  0.292949
# Tm      0.953719  0.892031  1.000000 -0.917518 -0.287357  0.577240  0.296225
# SLP    -0.881409 -0.822958 -0.917518  1.000000  0.240256 -0.517915 -0.329838
# H      -0.509299 -0.586681 -0.287357  0.240256  1.000000 -0.465374 -0.380575
# VV      0.640792  0.606945  0.577240 -0.517915 -0.465374  1.000000  0.376873
# V       0.301994  0.292949  0.296225 -0.329838 -0.380575  0.376873  1.000000
# VM      0.287738  0.297011  0.266782 -0.310704 -0.362177  0.342442  0.775655
# PM 2.5 -0.631462 -0.568409 -0.673824  0.623187  0.138005 -0.573941 -0.268530
#
#               VM    PM 2.5
# T       0.287738 -0.631462
# TM      0.297011 -0.568409
# Tm      0.266782 -0.673824
# SLP    -0.310704  0.623187
# H      -0.362177  0.138005
# VV      0.342442 -0.573941
# ...

# %%
plt.figure(figsize =(20,20))
sns.heatmap(data.corr())

# %%
from sklearn.ensemble import ExtraTreesRegressor
model =ExtraTreesRegressor()
model.fit(real_x,real_y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.19607046 0.08809017 0.20811821 0.12424412 0.08663189 0.19968277
#  0.05445787 0.0427045 ]

# %%
#plot graph of feature importances for batter visulization

fear_importances =pd.Series(model.feature_importances_,index =real_x.columns)
fear_importances.nlargest(10).plot(kind="barh")
plt.show()

# %% [markdown]
# # linear Regression

# %%
sns.distplot(real_y)

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y =train_test_split(real_x,real_y,test_size =0.3,random_state =0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor =LinearRegression()
regressor.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
regressor.score(train_x,train_y)
# Out:
# 0.551516808175875

# %%
regressor.score(test_x,test_y)
# Out:
# 0.485253313085679

# %%
from sklearn.model_selection import cross_val_score
score =cross_val_score(regressor,real_x,real_y,cv =5)

# %%
score
# Out:
# array([0.51616617, 0.43816894, 0.50733957, 0.4861091 , 0.40750087])

# %%
score.mean()
# Out:
# 0.4710569304807393

# %%
regressor.coef_
# Out:
# array([ -2.69090829,   0.46219975,  -3.86705184,  -0.04494855,
#         -1.21193616, -40.11490762,  -2.53563257,   0.56148181])

# %%
coeff_df =pd.DataFrame(regressor.coef_,real_x.columns,columns =["Coefficient"])
coeff_df
# Out:
#      Coefficient
# T      -2.690908
# TM      0.462200
# Tm     -3.867052
# SLP    -0.044949
# H      -1.211936
# VV    -40.114908
# V      -2.535633
# VM      0.561482

# %%
y_pred =regressor.predict(train_x)
y_pred0 =regressor.predict(test_x)

# %%
sns.distplot(train_y-y_pred)

# %%
sns.distplot(test_y-y_pred0)

# %%
plt.scatter(train_y,y_pred)()

# %%
plt.scatter(test_y,y_pred0)

# %%
from sklearn import metrics
print("MAE:" ,metrics.mean_absolute_error(train_y,y_pred))
print("MSE:" ,metrics.mean_squared_error(train_y,y_pred))
print("RMAE:" ,np.sqrt(metrics.mean_squared_error(train_y,y_pred)))
# Out:
# MAE: 41.63460229932238
# MSE: 3180.5755221020963
# RMAE: 56.396591404996244

# %%
from sklearn import metrics
print("MAE:" ,metrics.mean_absolute_error(test_y,y_pred0))
print("MSE:" ,metrics.mean_squared_error(test_y,y_pred0))
print("RMAE:" ,np.sqrt(metrics.mean_squared_error(test_y,y_pred0)))
# Out:
# MAE: 44.83624126628639
# MSE: 3687.543030932418
# RMAE: 60.72514331751238

# %%
#linear Regession
from sklearn.model_selection import cross_val_score

# %%
lin_regressor =LinearRegression()
mse =cross_val_score(lin_regressor,real_x,real_y,scoring ="neg_mean_squared_error",cv=5)
mean_mse =np.mean(mse)
print(mean_mse)
# Out:
# -3686.2017773398848

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge =Ridge()
parameters ={"alpha":[1e-15,1e-10,1e-8,1e-2,1,5,10,20,30,35,40]}
ridge_regressor =GridSearchCV(ridge,parameters,scoring ="neg_mean_squared_error",cv =5)
ridge_regressor.fit(real_x,real_y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.01, 1, 5, 10, 20, 30,
#                                    35, 40]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 40}
# -3664.364899607174

# %%
ridge =Ridge(alpha=40)
ridge.fit(train_x,train_y)
# Out:
# Ridge(alpha=40)

# %%
ridge.score(train_x,train_y)
# Out:
# 0.549924219035496

# %%
ridge.score(test_x,test_y)
# Out:
# 0.4862914772769469

# %%
from sklearn.linear_model import Lasso
lasso =Lasso()
parameters ={"alpha":[1e-15,1e-10,1e-8,1e-2,1,5,10,20,30,35,40]}
lasso_regressor =GridSearchCV(lasso,parameters,scoring ="neg_mean_squared_error",cv =5)
lasso_regressor.fit(real_x,real_y)
# Out:
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1444308.4069923554, tolerance: 614.5592033746459
#   positive)
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1568739.8013245857, tolerance: 678.9710639134809
#   positive)
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1456481.2344420976, tolerance: 626.8737580831347
#   positive)
# ...

# %%
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 1}
# -3666.78325343702

# %%
lasso =Lasso(alpha=5)
lasso.fit(train_x,train_y)
# Out:
# Lasso(alpha=5)

# %%
lasso.score(train_x,train_y)
# Out:
# 0.5392415536621153

# %%
lasso.score(test_x,test_y)
# Out:
# 0.4810050930885592

# %%
#model Evalution
pred_y11=lasso_regressor.predict(test_x)
sns.distplot(test_y-pred_y11)

# %%
from sklearn import metrics
print("MAE:" ,metrics.mean_absolute_error(test_y,pred_y11))
print("MSE:" ,metrics.mean_squared_error(test_y,pred_y11))
print("RMAE:" ,np.sqrt(metrics.mean_squared_error(test_y,pred_y11)))
# Out:
# MAE: 44.50831198875126
# MSE: 3627.8109390424697
# RMAE: 60.2313119485411

# %%
#dicision tress

# %%
data.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
sns.distplot(real_y)

# %%
 from sklearn.tree import DecisionTreeRegressor

# %%
dtree =DecisionTreeRegressor()

# %%
dtree.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y =train_test_split(real_x,real_y,test_size =0.3,random_state =0)

# %%
print(dtree.score(train_x,train_y))
print(dtree.score(test_x,test_y))
# Out:
# 1.0
# 0.6514740239930672

# %%
score =cross_val_score(dtree,real_x,real_y,cv =5)

# %%
score.mean()
# Out:
# 0.44937173643082867

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
plt.figure(figsize =(55,50))
tree.plot_tree(dtree,filled =True)
# Out:
# [Text(1703.4793516227833, 2653.285714285714, 'X[3] <= 1010.85\nmse = 6998.453\nsamples = 515\nvalue = 106.967'),
#  Text(783.6319089442053, 2523.857142857143, 'X[4] <= 64.5\nmse = 1955.208\nsamples = 306\nvalue = 63.667'),
#  Text(277.1731896423802, 2394.4285714285716, 'X[1] <= 36.65\nmse = 2416.6\nsamples = 145\nvalue = 85.437'),
#  Text(114.76302121976553, 2265.0, 'X[4] <= 61.0\nmse = 4333.289\nsamples = 25\nvalue = 135.205'),
#  Text(72.1367561952812, 2135.5714285714284, 'X[6] <= 11.4\nmse = 3797.834\nsamples = 18\nvalue = 156.563'),
#  Text(51.00578720878468, 2006.1428571428573, 'X[3] <= 1010.55\nmse = 3854.888\nsamples = 9\nvalue = 197.481'),
#  Text(32.060780531236084, 1876.7142857142858, 'X[1] <= 34.15\nmse = 1779.484\nsamples = 7\nvalue = 223.048'),
#  Text(11.658465647722213, 1747.2857142857142, 'X[5] <= 4.5\nmse = 196.882\nsamples = 3\nvalue = 176.319'),
#  Text(5.829232823861107, 1617.857142857143, 'mse = 0.0\nsamples = 1\nvalue = 194.708'),
# ...

# %%
print(tree.export_text(dtree))
# Out:
# |--- feature_3 <= 1010.85
# |   |--- feature_4 <= 64.50
# |   |   |--- feature_1 <= 36.65
# |   |   |   |--- feature_4 <= 61.00
# |   |   |   |   |--- feature_6 <= 11.40
# |   |   |   |   |   |--- feature_3 <= 1010.55
# |   |   |   |   |   |   |--- feature_1 <= 34.15
# |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |--- value: [194.71]
# |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 55.00
# |   |   |   |   |   |   |   |   |   |--- value: [160.67]
# |   |   |   |   |   |   |   |   |--- feature_4 >  55.00
# |   |   |   |   |   |   |   |   |   |--- value: [173.58]
# |   |   |   |   |   |   |--- feature_1 >  34.15
# |   |   |   |   |   |   |   |--- feature_6 <= 8.45
# |   |   |   |   |   |   |   |   |--- feature_2 <= 20.95
# |   |   |   |   |   |   |   |   |   |--- value: [272.42]
# |   |   |   |   |   |   |   |   |--- feature_2 >  20.95
# ...

# %%
pred_y1 =dtree.predict(train_x)

# %%
sns.distplot(train_y-pred_y1)
# Out:
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
plt.scatter(train_y,pred_y1)

# %%
pred_y2 =dtree.predict(test_x)
sns.distplot(test_y-pred_y2)

# %%
plt.scatter(test_y,pred_y2)

# %%
##Hyperparameter TUning DEcision Tree Regresson

# %%
DecisionTreeRegressor()
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
## Hyper Parameter Optimization

params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_samples_leaf" : [ 1,2,3,4,5 ],
"min_weight_fraction_leaf":[0.1,0.2,0.3,0.4],
 "max_features" : ["auto","log2","sqrt",None ],
    "max_leaf_nodes":[None,10,20,30,40,50,60,70]
    
}

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_mean_squared_error',n_jobs=-1,cv=10,verbose=3)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
from datetime import datetime
# Here we go
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(real_x,real_y)
timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 10 folds for each of 10240 candidates, totalling 102400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 1228 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 3788 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 7372 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 11980 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 17612 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 24268 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 31948 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 40652 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 50380 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 61132 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 72908 tasks      | elapsed:  3.9min
# ...

# %%
print(random_search.best_params_)
# Out:
# {'max_depth': 6, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.1, 'splitter': 'best'}

# %%
random_search.best_score_
# Out:
# -3131.6489619178874

# %%
pred_y3 =random_search.predict(test_x)

# %%
sns.distplot(test_y-pred_y3)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(test_y, pred_y3))
print('MSE:', metrics.mean_squared_error(test_y, pred_y3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test_y, pred_y3)))
# Out:
# MAE: 40.14163092473942
# MSE: 3171.808145980198
# RMSE: 56.31880810155874

# %%
#random forestregressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor =RandomForestRegressor()
regressor.fit(train_x,train_y)
# Out:
# RandomForestRegressor()

# %%
print(regressor.score(test_x,test_y))
print(regressor.score(train_x,train_y))
# Out:
# 0.787991540633372
# 0.9737585775969902

# %%
from sklearn.model_selection import cross_val_score
score =cross_val_score(regressor,real_x,real_y,cv=5)

# %%
score.mean()
# Out:
# 0.7290314984990593

# %%
#model evolution

# %%
pred_y4 =regressor.predict(test_x)
pred_y5 =regressor.predict(train_x)

# %%
sns.distplot(test_y-pred_y4)

# %%
sns.distplot(train_y-pred_y5)

# %%
plt.scatter(test_y,pred_y4)

# %%
plt.scatter(train_y,pred_y5)

# %%
#hyperparameter Tuning

# %%
rf =RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
print(n_estimators)
print(max_depth)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]
# [5, 10, 15, 20, 25, 30]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator =rf,param_distributions =random_grid,scoring ='neg_mean_squared_error',n_iter =100,cv =5,verbose =2,random_state =42)

# %%
rf_random.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
rf_random.best_score_
# Out:
# -1549.6219443395069

# %%
pred_y6 =rf_random.predict(test_x)
pred_y7 =rf_random.predict(train_x)

# %%
sns.distplot(test_y-pred_y6)

# %%
plt.scatter(test_y,pred_y6)

# %%
sns.distplot(train_y-pred_y7)

# %%
plt.scatter(train_y,pred_y7)

# %%
from sklearn import metrics
print("MAE:" ,metrics.mean_absolute_error(test_y,pred_y6))
print("MSE:" ,metrics.mean_squared_error(test_y,pred_y6))
print("RMAE:" ,np.sqrt(metrics.mean_squared_error(test_y,pred_y6)))
# Out:
# MAE: 24.562220119776242
# MSE: 1664.2009872396718
# RMAE: 40.79461958689738

# %%
ANN ALGORITHMS

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU

# %%
classifier =Sequential()

# %%
classifier.add(Dense(128,kernel_initializer ="normal",activation ="relu",input_dim =train_x.shape[1]))
classifier.add(Dense(256,kernel_initializer ="normal",activation ="relu"))
classifier.add(Dense(256,kernel_initializer ="normal",activation ="relu"))
classifier.add(Dense(1,  kernel_initializer ="normal",activation ="linear"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-50c3eac785ab> in <module>
# ----> 1 classifier.add(Dense(128,kernel_initializer ="normal",activation ="relu",input_dim =train_x.shape[1]))
#       2 classifier.add(Dense(256,kernel_initializer ="normal",activation ="relu"))
#       3 classifier.add(Dense(256,kernel_initializer ="normal",activation ="relu"))
#       4 classifier.add(Dense(1,  kernel_initializer ="normal",activation ="linear"))
#
# NameError: name 'train_x' is not defined

# %%
classifier.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-720ff4421f43> in <module>
# ----> 1 classifier.summary()
#
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\network.py in summary(self, line_length, positions, print_fn)
#    1344     """
#    1345     if not self.built:
# -> 1346       raise ValueError('This model has not yet been built. '
#    1347                        'Build the model first by calling `build()` or calling '
#    1348                        '`fit()` with some data, or specify '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data, or specify an `input_shape` argument in the first layer(s) for automatic build.

# %%
classifier.compile(optimizer ="adam",loss ="mean_absolute_error",metrics =["mean_absolute_error"])

# %%
model_history =classifier.fit(train_x,train_y,validation_split =0.33,batch_size =10,epochs=100)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 7ms/step - loss: 55.2534 - mean_absolute_error: 55.2534 - val_loss: 44.7500 - val_mean_absolute_error: 44.7500
# Epoch 2/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.6393 - mean_absolute_error: 42.6393 - val_loss: 44.5998 - val_mean_absolute_error: 44.5998
# Epoch 3/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.6682 - mean_absolute_error: 40.6682 - val_loss: 46.0856 - val_mean_absolute_error: 46.0856
# Epoch 4/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.5944 - mean_absolute_error: 42.5944 - val_loss: 45.2133 - val_mean_absolute_error: 45.2133
# Epoch 5/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.7402 - mean_absolute_error: 40.7402 - val_loss: 44.0794 - val_mean_absolute_error: 44.0794
# Epoch 6/100
# ...
